# %%
from ultralytics import YOLO

# Load model
model = YOLO("model101.pt")  # or yolov5s.pt if using v5

# Check class names
print(model.names)           # dictionary {class_id: class_name}
# Out:
# {0: 'bike', 1: 'car', 2: 'person_with_ID', 3: 'person_without_ID'}
# bike

# %%
from ultralytics import YOLO

# Load model
model = YOLO("custom_yolo_v3.pt")  # or yolov5s.pt if using v5

# Check class names
print(model.names)           # dictionary {class_id: class_name}
# Out:
# {0: 'person_with_ID', 1: 'person_without_ID'}
